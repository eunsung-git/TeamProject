# %%
api_key = '%2FJgRrmm9JXaictz6llfBiClpFH5LGECjqZivf5V4Y5HwPgZLMmP38Ho6nqNdwp%2B%2B5z2qvJG6FeelYhnTh9yV%2Bg%3D%3D'
pageNo = 1
numOfRows = 10
base_date = 20200616
nx = 55
ny = 127

# %%
# Python 샘플 코드 #

import requests

url = 'http://apis.data.go.kr/1360000/VilageFcstInfoService/getUltraSrtNcst'
queryParams = '?' + 'ServiceKey='+api_key + '&pageNo='+str(pageNo) + '&numOfRows='+str(numOfRows) + '&dataType=JSON' + '&base_date='+str(base_date)+ '&base_time=1400'+ '&nx='+str(nx) + '&ny='+str(ny)

response = requests.get(url + queryParams)
data = response.json()
print(data)
# Out:
# {'response': {'header': {'resultCode': '10', 'resultMsg': '최근 1일 간의 자료만 제공합니다.'}}}

# %%
# category : PTY 0, REH 76, RN1 0, T1H 20.5, UUU -0.1, VEC 23, VVV -0.4, WSD 0.5

# %%
import requests
from bs4 import BeautifulSoup

# %%
source = requests.get('https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query='+'서울특별시+종로구+청운효자동+날씨').text
source
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="서울특별시 종로구 청운효자동 날씨 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'서울특별시 종로구 청운효자동 날씨\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'서울특별시 종로구 청운효자동 날씨\'의 네이버 통합검색 결과입니다."> <title>서울특별시 종로구 청운효자동 날씨 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/se
# ...

# %%
soup = BeautifulSoup(source, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
# ws1 : 해, ws5 : 구름많음, ws7:흐림, ws9 : 비

# %%
icon = soup.select(' .date_info .point_time .ico_state2')
for i in icon :
    print(i.get('class')[1])
# Out:
# ws1
# ws1
# ws1
# ws1
# ws1
# ws1
# ws5
# ws5
# ws7
# ws9
# ws9
# ws9
# ws9
# ws5
# ws5
# ws5
# ws7
# ws7
# ws9
# ws9

# %%
cel = soup.select('li.date_info > dl > dd > span')
for c in cel :
    print(c.get_text())
# Out:
# 21
# /
# 30
# 20
# /
# 32
# 21
# /
# 34
# 23
# /
# 33
# 22
# /
# 28
# 21
# /
# 27
# 21
# /
# 29
# 21
# /
# 29
# 21
# /
# 29
# 22
# /
# 28
